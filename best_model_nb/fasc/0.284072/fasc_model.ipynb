# %% [markdown]
# # Segmentation
#
# * fasc

# %%
from PIL import Image
import os
import hashlib
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
import torch.nn as nn
import time
from datetime import datetime, timezone, timedelta

try:
    from google.colab import drive
    from google.colab import runtime
    is_colab = True
except ImportError:
    is_colab = False

if is_colab:

    drive.mount("/content/drive")

    # !mkdir -p /content/my_dataset
    # !unzip -q -o "/content/drive/MyDrive/colab/UMUD/umud-challenge-muscle-architecture-in-ultrasound-data.zip" -d /content/my_dataset/

    data_dir = "/content/my_dataset"
    model_output_dir = "/content/drive/MyDrive/colab/UMUD"

else:

    data_dir = "content/my_dataset"
    model_output_dir = "segmentation_baseline_models"


jst = timezone(timedelta(hours=9))
execution_start_datetime = datetime.now(jst)
execution_start_time = time.perf_counter()

print("=============================================")
print(
    "実行開始時間:",
    execution_start_datetime.strftime("%Y-%m-%d %H:%M:%S JST")
)
print("=============================================")


device_check = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "cpu"
)

print("device:", device_check)

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))



def load_fasc_binary_mask(mask_dir, file_name):
    """
    fasc mask を
    背景=0
    fascicle=1
    の二値配列に変換する
    """
    mask = Image.open(os.path.join(mask_dir, file_name))
    mask_array = np.array(mask)

    if mask.mode == "L":
        binary_mask = (mask_array == 255).astype(np.uint8)
    else:
        raise ValueError(f"未対応のmodeです: {mask.mode}")

    return binary_mask


def calculate_sha256(file_path):
    """
    ファイルのSHA-256を計算する
    """
    sha256 = hashlib.sha256()

    with open(file_path, "rb") as f:
        while True:
            chunk = f.read(1024 * 1024)

            if not chunk:
                break

            sha256.update(chunk)
    return sha256.hexdigest()


def resize_with_padding(image, mask, target_size=(768, 512)):
    """
    image と mask の縦横比を維持したまま縮小し、
    target_size まで余白を追加する
    """

    target_width, target_height = target_size
    original_width, original_height = image.size

    scale = min(target_width / original_width, target_height / original_height)
    new_width = int(original_width * scale)
    new_height = int(original_height * scale)


    image = image.resize((new_width, new_height), resample=Image.Resampling.BILINEAR)
    mask = mask.resize((new_width, new_height), resample=Image.Resampling.NEAREST)
    left = (target_width - new_width) // 2
    top = (target_height - new_height) // 2
    image_canvas = Image.new(image.mode, target_size, 0)
    mask_canvas = Image.new("L", target_size, 0)
    image_canvas.paste(image, (left, top))
    mask_canvas.paste(mask, (left, top))

    return image_canvas, mask_canvas


class SegmentationDataset(Dataset):

    def __init__(self, image_dir, mask_dir, mask_loader):

        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.mask_loader = mask_loader

        image_files = sorted([
            f for f in os.listdir(image_dir)
            if f.lower().endswith(
                (".tif", ".tiff", ".png", ".jpg", ".jpeg")
            )
        ])

        #image + mask が完全一致する重複を除去
        unique_image_files = []
        seen_pairs = set()

        for file_name in image_files:

            image_path = os.path.join(image_dir, file_name)
            mask_path = os.path.join(mask_dir, file_name)

            image_hash = calculate_sha256(image_path)
            mask_hash = calculate_sha256(mask_path)

            pair_hash = (image_hash, mask_hash)

            if pair_hash in seen_pairs:
                continue

            seen_pairs.add(pair_hash)
            unique_image_files.append(file_name)

        self.image_files = unique_image_files

        print("=============================================")
        print("""

        From the URL discussion below, there is duplicate data in the official dataset.
        To prevent data leak between train / validation
        Duplicate deletion processed

        下記URLディスカッションより、公式datasetに重複データがあり、
        train / validation間のデータリークを防止する為
        重複削除処理しました。.....

        引用
        https://www.kaggle.com/competitions/umud-challenge-muscle-architecture-in-ultrasound-data/discussion/740356

        """)
        print("Dataset duplicate removal")
        print("before:", len(image_files))
        print("after:", len(self.image_files))
        print("removed:", len(image_files) - len(self.image_files))
        print("=============================================")



    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, index):

        file_name = self.image_files[index]
        image_path = os.path.join(self.image_dir, file_name)
        image = Image.open(image_path).convert("RGB")
        mask = self.mask_loader(self.mask_dir, file_name)

        #maskとimageをサイズ揃える
        mask = Image.fromarray(mask)
        mask = mask.resize(image.size, resample=Image.Resampling.NEAREST)

        image, mask = resize_with_padding(image, mask, target_size=(768, 512))

        # image → numpy → Tensor
        image = np.array(image)
        image = torch.from_numpy(image).float() / 255.0
        image = image.permute(2, 0, 1)

        # mask → numpy → Tensor
        mask = np.array(mask)
        mask = torch.from_numpy(mask).float()
        mask = mask.unsqueeze(0)

        return image, mask


class DoubleConv(nn.Module):

    def __init__(self, in_channels, out_channels):

        super().__init__()

        self.conv = nn.Sequential(

            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.conv(x)


class UNet(nn.Module):

    def __init__(self):
        super().__init__()

        # Encoder
        self.enc1 = DoubleConv(3, 64)
        self.pool1 = nn.MaxPool2d(2)

        self.enc2 = DoubleConv(64, 128)
        self.pool2 = nn.MaxPool2d(2)

        self.enc3 = DoubleConv(128, 256)
        self.pool3 = nn.MaxPool2d(2)

        self.enc4 = DoubleConv(256, 512)
        self.pool4 = nn.MaxPool2d(2)

        # Bottleneck
        self.bottleneck = DoubleConv(512, 1024)

        # Decoder
        self.up4 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.dec4 = DoubleConv(1024, 512)
        self.up3 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.dec3 = DoubleConv(512, 256)
        self.up2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec2 = DoubleConv(256, 128)
        self.up1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec1 = DoubleConv(128, 64)

        # 出力
        self.output = nn.Conv2d(64, 1, kernel_size=1)

    def forward(self, x):

        enc1 = self.enc1(x)
        enc2 = self.enc2(self.pool1(enc1))
        enc3 = self.enc3(self.pool2(enc2))
        enc4 = self.enc4(self.pool3(enc3))

        bottleneck = self.bottleneck(self.pool4(enc4))

        dec4 = self.up4(bottleneck)
        dec4 = torch.cat((dec4, enc4), dim=1)
        dec4 = self.dec4(dec4)

        dec3 = self.up3(dec4)
        dec3 = torch.cat((dec3, enc3), dim=1)
        dec3 = self.dec3(dec3)

        dec2 = self.up2(dec3)
        dec2 = torch.cat((dec2, enc2), dim=1)
        dec2 = self.dec2(dec2)

        dec1 = self.up1(dec2)
        dec1 = torch.cat((dec1, enc1), dim=1)
        dec1 = self.dec1(dec1)

        return self.output(dec1)

class DiceLoss(nn.Module):

    def __init__ (self):
        super().__init__()

    def forward(self, outputs, masks):
        pred_probs = torch.sigmoid(outputs)
        intersection = (pred_probs * masks).sum()
        dice = (2 * intersection) / (pred_probs.sum() + masks.sum())
        return 1 - dice

# Dataset作成 → 学習 → 保存 → Dice
def run_segmentation(
    image_dir,
    mask_dir,
    mask_loader,
    model_save_name,
    label_name,
    thresholds,
    global_best_dice,
    lr=0.001,
    batch_size=2,
    num_epochs=50,
    pos_weight=None
):

    print()
    print("=============================================")
    print(f"{label_name} segmentation")
    print("=============================================")

    # Dataset

    dataset = SegmentationDataset(image_dir, mask_dir, mask_loader)
    train_size = int(len(dataset) * 0.8)
    val_size = (len(dataset) - train_size)

    generator = (torch.Generator().manual_seed(42))
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size], generator=generator)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


    #設定

    device = torch.device(
        "cuda"
        if torch.cuda.is_available()
        else "cpu"
    )

    print("device:", device)

    torch.manual_seed(42)
    torch.cuda.manual_seed_all(42)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    #モデル

    model = UNet()
    model = model.to(device)

    if pos_weight is None:
        bce_criterion = nn.BCEWithLogitsLoss()
    else:
        pos_weight_tensor = torch.tensor([pos_weight], dtype=torch.float32, device=device)
        bce_criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight_tensor)
        print("pos_weight:", pos_weight)

    dice_criterion = DiceLoss()

    optimizer = torch.optim.Adam(
        model.parameters(),                             #U-Netの学習対象パラメータ
        lr=lr                                           #1回の更新幅
    )

    best_val_dice = -1
    best_val_loss = None
    best_train_loss = None
    best_epoch = 0
    best_threshold = None


    #学習

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0

        for images, masks in train_loader:

            images = images.to(device)
            masks = masks.to(device)
            optimizer.zero_grad()
            outputs = model(images)

            loss = bce_criterion(outputs, masks) + dice_criterion(outputs, masks)

            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        train_loss = (total_loss / len(train_loader))

        # validation

        model.eval()

        val_total_loss = 0

        intersection_totals = {
            threshold: 0
            for threshold in thresholds
        }

        pred_totals = {
            threshold: 0
            for threshold in thresholds
        }

        true_total = 0


        with torch.no_grad():
            for images, masks in val_loader:
                images = images.to(device)
                masks = masks.to(device)
                outputs = model(images)

                loss = bce_criterion(outputs, masks) + dice_criterion(outputs, masks)

                val_total_loss += loss.item()
                pred_probs = torch.sigmoid(outputs)

                for threshold in thresholds:
                    pred_masks = (pred_probs >= threshold).float()

                    intersection_totals[threshold] += (pred_masks * masks).sum().item()
                    pred_totals[threshold] += pred_masks.sum().item()

                true_total += masks.sum().item()

        val_loss = (val_total_loss / len(val_loader))

        epoch_best_threshold = None
        epoch_best_dice = -1

        for threshold in thresholds:

            dice = (2 * intersection_totals[threshold]) / (pred_totals[threshold] + true_total)

            if dice > epoch_best_dice:
                epoch_best_threshold = threshold
                epoch_best_dice = dice

        val_dice = epoch_best_dice

        print("=============================================")
        print(
            f"{label_name} "
            f"epoch: {epoch + 1}/{num_epochs}"
        )
        print("train loss:", train_loss)
        print("validation loss:", val_loss)
        print("validation Dice:", val_dice)
        print("validation best threshold:", epoch_best_threshold)

        #この条件内でDice最大の結果を保存

        if val_dice > best_val_dice:
            best_val_dice = val_dice
            best_val_loss = val_loss
            best_train_loss = train_loss
            best_epoch = epoch + 1
            best_threshold = epoch_best_threshold

        if val_dice > global_best_dice:
            global_best_dice = val_dice

            torch.save(
                {
                    "model_state_dict": model.state_dict(),
                    "best_threshold": epoch_best_threshold,
                    "best_validation_dice": global_best_dice,
                    "best_epoch": epoch + 1,
                    "lr": lr,
                    "pos_weight": pos_weight
                },
                model_save_name
            )

            print()
            print("***** GLOBAL BEST UPDATE *****")
            print("model:", model_save_name)
            print("Dice:", global_best_dice)
            print("threshold:", epoch_best_threshold)
            print("epoch:", epoch + 1)
            print("lr:", lr)
            print("pos_weight:", pos_weight)
            print("******************************")

    # 学習結果

    print(f"""
=================================================
{label_name}
lr: {lr}
pos_weight: {pos_weight}
train loss: {best_train_loss}
validation loss: {best_val_loss}
best epoch: {best_epoch}
best validation Dice: {best_val_dice}
best threshold: {best_threshold}
=================================================
""")


    return {
        "label_name": label_name,
        "train_loss": best_train_loss,
        "validation_loss": best_val_loss,
        "best_epoch": best_epoch,
        "best_validation_dice": best_val_dice,
        "best_threshold": best_threshold,
        "dice": best_val_dice,
        "lr": lr,
        "pos_weight": pos_weight,
        "global_best_dice": global_best_dice
    }


#_/_/_/_/_/_/_/_/_/_/_/_/fasc_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/


fasc_images_new_model_v1 = os.path.join(data_dir, "fasc_imgs_v1", "fasc_images_new_model_v1")
fasc_masks_new_model_v1 = os.path.join(data_dir, "fasc_masks_v1", "fasc_masks_new_model_v1")

fasc_thresholds = [
    0.30, 0.32, 0.34, 0.36, 0.38,
    0.40, 0.42, 0.44, 0.46, 0.48,
    0.50, 0.52, 0.54, 0.56, 0.58,
    0.60, 0.62, 0.64, 0.66, 0.68,
    0.70, 0.72, 0.74, 0.76, 0.78,
    0.80, 0.82, 0.84, 0.86, 0.88,
    0.90
]

fasc_lr = 0.0006

fasc_pos_weights = [8, 12]

fasc_results = []
fasc_best_result = None
fasc_global_best_dice = -1

model_save_name = os.path.join(model_output_dir, "fasc_model.pth")


for fasc_pos_weight in fasc_pos_weights:

    label_name = f"fasc lr={fasc_lr} pos_weight={fasc_pos_weight}"

    fasc_result = run_segmentation(
        image_dir=fasc_images_new_model_v1,
        mask_dir=fasc_masks_new_model_v1,
        mask_loader=load_fasc_binary_mask,
        model_save_name=model_save_name,
        label_name=label_name,
        thresholds=fasc_thresholds,
        global_best_dice=fasc_global_best_dice,
        lr=fasc_lr,
        batch_size=2,
        num_epochs=40,
        pos_weight=fasc_pos_weight
    )

    fasc_global_best_dice = fasc_result["global_best_dice"]
    fasc_results.append(fasc_result)

    if (
        fasc_best_result is None
        or fasc_result["best_validation_dice"] > fasc_best_result["best_validation_dice"]
    ):
        fasc_best_result = fasc_result


#_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/_/

print()
print("=============================================")
print("FASC BEST RESULT")
print("=============================================")
print("lr:", fasc_best_result["lr"])
print("pos_weight:", fasc_best_result["pos_weight"])
print("best epoch:", fasc_best_result["best_epoch"])
print("best threshold:", fasc_best_result["best_threshold"])
print("validation loss:", fasc_best_result["validation_loss"])
print("best validation Dice:", fasc_best_result["best_validation_dice"])
print("model:", os.path.join(model_output_dir, "fasc_model.pth"))
print("=============================================")


#時間確認

execution_end_datetime = datetime.now(jst)
execution_elapsed_seconds = time.perf_counter() - execution_start_time

hours = int(execution_elapsed_seconds // 3600)
minutes = int((execution_elapsed_seconds % 3600) // 60)
seconds = int(execution_elapsed_seconds % 60)

print()
print("=============================================")
print(
    "実行開始時間:",
    execution_start_datetime.strftime("%Y-%m-%d %H:%M:%S JST")
)
print(
    "すべての処理が終了した時間:",
    execution_end_datetime.strftime("%Y-%m-%d %H:%M:%S JST")
)
print(
    "総処理時間:",
    f"{hours:02d}:{minutes:02d}:{seconds:02d}"
)
print("=============================================")


if is_colab:

    print("Google Driveへの書き込みを確定します")
    drive.flush_and_unmount()

    print("Google Driveへの保存が完了しました")
    print("Colabランタイムを切断します")

    runtime.unassign()
# Out:
# Mounted at /content/drive
# =============================================
# 実行開始時間: 2026-09-25 19:16:42 JST
# =============================================
# device: cuda
# GPU: NVIDIA A100-SXM4-80GB
#
# =============================================
# fasc lr=0.0006 pos_weight=8 segmentation
# =============================================
# =============================================
#
#
#         From the URL discussion below, there is duplicate data in the official dataset.
#         To prevent data leak between train / validation
#         Duplicate deletion processed
#
#         下記URLディスカッションより、公式datasetに重複データがあり、
#         train / validation間のデータリークを防止する為
#         重複削除処理しました。.....
#
#         引用
#         https://www.kaggle.com/competitions/umud-challenge-muscle-architecture-in-ultrasound-data/discussion/740356
#
#
# Dataset duplicate removal
# before: 2761
# after: 2091
# removed: 670
# =============================================
# device: cuda
# pos_weight: 8
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 1/40
# train loss: 1.0077651158759469
# validation loss: 0.944488495304471
# validation Dice: 0.19261516850409502
# validation best threshold: 0.34
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.19261516850409502
# threshold: 0.34
# epoch: 1
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 2/40
# train loss: 0.9217961325742411
# validation loss: 0.9068815512316567
# validation Dice: 0.22115176315639085
# validation best threshold: 0.84
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.22115176315639085
# threshold: 0.84
# epoch: 2
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 3/40
# train loss: 0.9019326233977907
# validation loss: 0.8991124882584527
# validation Dice: 0.22445245493448213
# validation best threshold: 0.42
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.22445245493448213
# threshold: 0.42
# epoch: 3
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 4/40
# train loss: 0.8935693578001415
# validation loss: 0.8985519338221777
# validation Dice: 0.22044565852522272
# validation best threshold: 0.82
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 5/40
# train loss: 0.887059079260347
# validation loss: 0.884328327860151
# validation Dice: 0.2324834008255307
# validation best threshold: 0.88
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.2324834008255307
# threshold: 0.88
# epoch: 5
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 6/40
# train loss: 0.8819240356603878
# validation loss: 0.8797919602621169
# validation Dice: 0.23588834991474844
# validation best threshold: 0.64
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.23588834991474844
# threshold: 0.64
# epoch: 6
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 7/40
# train loss: 0.8790540972537402
# validation loss: 0.8778247492653983
# validation Dice: 0.23784892980040367
# validation best threshold: 0.86
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.23784892980040367
# threshold: 0.86
# epoch: 7
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 8/40
# train loss: 0.8752891598848634
# validation loss: 0.8760707900637672
# validation Dice: 0.24215563498625212
# validation best threshold: 0.34
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.24215563498625212
# threshold: 0.34
# epoch: 8
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 9/40
# train loss: 0.8744464066040003
# validation loss: 0.8682306130727132
# validation Dice: 0.24559486572970637
# validation best threshold: 0.56
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.24559486572970637
# threshold: 0.56
# epoch: 9
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 10/40
# train loss: 0.8699034212879017
# validation loss: 0.8689211303279514
# validation Dice: 0.2456465156527412
# validation best threshold: 0.78
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.2456465156527412
# threshold: 0.78
# epoch: 10
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 11/40
# train loss: 0.8897570618316888
# validation loss: 0.8721783825329372
# validation Dice: 0.24257550182557394
# validation best threshold: 0.8
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 12/40
# train loss: 0.8685495385712985
# validation loss: 0.868567875453404
# validation Dice: 0.24396992529537656
# validation best threshold: 0.66
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 13/40
# train loss: 0.8646559713132074
# validation loss: 0.8727119738147372
# validation Dice: 0.24722723275836878
# validation best threshold: 0.72
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.24722723275836878
# threshold: 0.72
# epoch: 13
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 14/40
# train loss: 0.8634054142464861
# validation loss: 0.8639490212712969
# validation Dice: 0.2516805874887828
# validation best threshold: 0.48
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.2516805874887828
# threshold: 0.48
# epoch: 14
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 15/40
# train loss: 0.8595455155560845
# validation loss: 0.8637535330795106
# validation Dice: 0.2487825611922737
# validation best threshold: 0.62
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 16/40
# train loss: 0.8572647203669024
# validation loss: 0.8747795604524158
# validation Dice: 0.249681504269249
# validation best threshold: 0.9
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 17/40
# train loss: 0.8576815726511786
# validation loss: 0.8604801152433668
# validation Dice: 0.25462927822305736
# validation best threshold: 0.44
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.25462927822305736
# threshold: 0.44
# epoch: 17
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 18/40
# train loss: 0.8545225334652303
# validation loss: 0.8573995908101399
# validation Dice: 0.2552739507013861
# validation best threshold: 0.84
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.2552739507013861
# threshold: 0.84
# epoch: 18
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 19/40
# train loss: 0.8530379254281806
# validation loss: 0.8574433323882875
# validation Dice: 0.2580687015472445
# validation best threshold: 0.66
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.2580687015472445
# threshold: 0.66
# epoch: 19
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 20/40
# train loss: 0.8519308027325635
# validation loss: 0.8581705777418046
# validation Dice: 0.25489062304849225
# validation best threshold: 0.6
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 21/40
# train loss: 0.8473471355352675
# validation loss: 0.8601314306259156
# validation Dice: 0.2610633427601062
# validation best threshold: 0.42
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.2610633427601062
# threshold: 0.42
# epoch: 21
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 22/40
# train loss: 0.8471282987218154
# validation loss: 0.854574103582473
# validation Dice: 0.26325702368477644
# validation best threshold: 0.9
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.26325702368477644
# threshold: 0.9
# epoch: 22
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 23/40
# train loss: 0.8436930521823572
# validation loss: 0.8454214059171222
# validation Dice: 0.26315610871018935
# validation best threshold: 0.6
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 24/40
# train loss: 0.8430379227730647
# validation loss: 0.8443698088328043
# validation Dice: 0.2652246586951811
# validation best threshold: 0.68
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.2652246586951811
# threshold: 0.68
# epoch: 24
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 25/40
# train loss: 0.8413036000785645
# validation loss: 0.8491813827128637
# validation Dice: 0.2646154145454823
# validation best threshold: 0.68
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 26/40
# train loss: 0.8380319451886501
# validation loss: 0.8450641844953809
# validation Dice: 0.2669482121052943
# validation best threshold: 0.62
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.2669482121052943
# threshold: 0.62
# epoch: 26
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 27/40
# train loss: 0.8360823029964164
# validation loss: 0.8403743355047135
# validation Dice: 0.26779407860972976
# validation best threshold: 0.8
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.26779407860972976
# threshold: 0.8
# epoch: 27
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 28/40
# train loss: 0.8355692334865269
# validation loss: 0.842790029446284
# validation Dice: 0.2671720267265476
# validation best threshold: 0.8
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 29/40
# train loss: 0.8323013463801745
# validation loss: 0.8493162773904346
# validation Dice: 0.2616187989556136
# validation best threshold: 0.86
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 30/40
# train loss: 0.8313686400651932
# validation loss: 0.8417088329792023
# validation Dice: 0.270034025173947
# validation best threshold: 0.86
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.270034025173947
# threshold: 0.86
# epoch: 30
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 31/40
# train loss: 0.8310995832727286
# validation loss: 0.8396853935150873
# validation Dice: 0.27111612057811574
# validation best threshold: 0.84
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.27111612057811574
# threshold: 0.84
# epoch: 31
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 32/40
# train loss: 0.8295202639542127
# validation loss: 0.8352856062707447
# validation Dice: 0.27298802281155815
# validation best threshold: 0.76
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.27298802281155815
# threshold: 0.76
# epoch: 32
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 33/40
# train loss: 0.8260269088037847
# validation loss: 0.8379408827849797
# validation Dice: 0.26988564338624693
# validation best threshold: 0.72
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 34/40
# train loss: 0.8250486316720834
# validation loss: 0.8396278191180456
# validation Dice: 0.27034216248877724
# validation best threshold: 0.76
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 35/40
# train loss: 0.8248347567314166
# validation loss: 0.8411178021203904
# validation Dice: 0.27236847981421936
# validation best threshold: 0.44
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 36/40
# train loss: 0.8226593597368761
# validation loss: 0.8322779184296017
# validation Dice: 0.27487182559022855
# validation best threshold: 0.6
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.27487182559022855
# threshold: 0.6
# epoch: 36
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 37/40
# train loss: 0.8208710199765612
# validation loss: 0.8375153768630255
# validation Dice: 0.2744880568208029
# validation best threshold: 0.7
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 38/40
# train loss: 0.8191081711835269
# validation loss: 0.8377727573826199
# validation Dice: 0.2710637361202827
# validation best threshold: 0.76
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 39/40
# train loss: 0.8172316674553036
# validation loss: 0.835537584622701
# validation Dice: 0.2751000651849182
# validation best threshold: 0.78
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.2751000651849182
# threshold: 0.78
# epoch: 39
# lr: 0.0006
# pos_weight: 8
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=8 epoch: 40/40
# train loss: 0.8167619176886298
# validation loss: 0.8350998642898741
# validation Dice: 0.2747198726391518
# validation best threshold: 0.78
#
# =================================================
# fasc lr=0.0006 pos_weight=8
# lr: 0.0006
# pos_weight: 8
# train loss: 0.8172316674553036
# validation loss: 0.835537584622701
# best epoch: 39
# best validation Dice: 0.2751000651849182
# best threshold: 0.78
# =================================================
#
#
# =============================================
# fasc lr=0.0006 pos_weight=12 segmentation
# =============================================
# =============================================
#
#
#         From the URL discussion below, there is duplicate data in the official dataset.
#         To prevent data leak between train / validation
#         Duplicate deletion processed
#
#         下記URLディスカッションより、公式datasetに重複データがあり、
#         train / validation間のデータリークを防止する為
#         重複削除処理しました。.....
#
#         引用
#         https://www.kaggle.com/competitions/umud-challenge-muscle-architecture-in-ultrasound-data/discussion/740356
#
#
# Dataset duplicate removal
# before: 2761
# after: 2091
# removed: 670
# =============================================
# device: cuda
# pos_weight: 12
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 1/40
# train loss: 1.1597414072335621
# validation loss: 1.0093460943017687
# validation Dice: 0.17837667582726752
# validation best threshold: 0.42
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 2/40
# train loss: 1.041047670624473
# validation loss: 0.9725479563077291
# validation Dice: 0.20651227040093964
# validation best threshold: 0.46
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 3/40
# train loss: 0.9371421777745753
# validation loss: 0.9343166158312843
# validation Dice: 0.22488677311646665
# validation best threshold: 0.48
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 4/40
# train loss: 4.025427819296504
# validation loss: 1.6828138731774829
# validation Dice: 0.0
# validation best threshold: 0.3
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 5/40
# train loss: 1.0526511904440428
# validation loss: 1.0312062930493129
# validation Dice: 0.15808853367961964
# validation best threshold: 0.62
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 6/40
# train loss: 1.0209297818715493
# validation loss: 1.013356750352042
# validation Dice: 0.17402954905115894
# validation best threshold: 0.72
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 7/40
# train loss: 1.0053281816854431
# validation loss: 0.9737537068980081
# validation Dice: 0.1964413396233792
# validation best threshold: 0.78
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 8/40
# train loss: 0.9669469294080324
# validation loss: 0.9545140800021944
# validation Dice: 0.2048069649929978
# validation best threshold: 0.6
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 9/40
# train loss: 0.9389401254328814
# validation loss: 0.9325847790354774
# validation Dice: 0.22157746438330803
# validation best threshold: 0.56
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 10/40
# train loss: 0.9271149252447786
# validation loss: 0.9244519977342515
# validation Dice: 0.22532607646754924
# validation best threshold: 0.74
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 11/40
# train loss: 0.9223359468165767
# validation loss: 0.9140333340281532
# validation Dice: 0.22979591549772882
# validation best threshold: 0.78
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 12/40
# train loss: 0.9160700629344968
# validation loss: 0.9110283088116419
# validation Dice: 0.23519306535404352
# validation best threshold: 0.68
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 13/40
# train loss: 0.9121521062542948
# validation loss: 0.9182452741123381
# validation Dice: 0.23165255527191014
# validation best threshold: 0.84
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 14/40
# train loss: 0.9094001029809696
# validation loss: 0.9103841685113453
# validation Dice: 0.2397638778521966
# validation best threshold: 0.44
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 15/40
# train loss: 0.9025368802427676
# validation loss: 0.9085268999849047
# validation Dice: 0.23927765844624968
# validation best threshold: 0.66
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 16/40
# train loss: 0.8990500674863752
# validation loss: 0.9277520108790624
# validation Dice: 0.23402523098526326
# validation best threshold: 0.9
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 17/40
# train loss: 0.8984561257385181
# validation loss: 0.8906749157678513
# validation Dice: 0.25260419382446453
# validation best threshold: 0.76
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 18/40
# train loss: 0.8929164485925692
# validation loss: 0.8908852125917163
# validation Dice: 0.24887245264972788
# validation best threshold: 0.82
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 19/40
# train loss: 0.8898048659688548
# validation loss: 0.890139263016837
# validation Dice: 0.25334098692272544
# validation best threshold: 0.84
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 20/40
# train loss: 0.89233456017298
# validation loss: 0.8982319829009828
# validation Dice: 0.2506522637150304
# validation best threshold: 0.72
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 21/40
# train loss: 0.8847877925092523
# validation loss: 0.886553590638297
# validation Dice: 0.25800281758154653
# validation best threshold: 0.74
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 22/40
# train loss: 0.8828063617910494
# validation loss: 0.8905737275169009
# validation Dice: 0.25407154736279597
# validation best threshold: 0.9
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 23/40
# train loss: 0.8785679502920671
# validation loss: 0.8788383208570026
# validation Dice: 0.26073505399753644
# validation best threshold: 0.84
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 24/40
# train loss: 0.8799818242993651
# validation loss: 0.889200189283916
# validation Dice: 0.2519213203068048
# validation best threshold: 0.48
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 25/40
# train loss: 0.8742704673817283
# validation loss: 0.8797925634043557
# validation Dice: 0.26451991259564633
# validation best threshold: 0.68
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 26/40
# train loss: 0.8751214515934721
# validation loss: 0.8705619181905474
# validation Dice: 0.2660123679750581
# validation best threshold: 0.68
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 27/40
# train loss: 0.8690130047535782
# validation loss: 0.869022725593476
# validation Dice: 0.2689768732704728
# validation best threshold: 0.88
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 28/40
# train loss: 0.867513885053151
# validation loss: 0.8670519925299145
# validation Dice: 0.27068114853236575
# validation best threshold: 0.72
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 29/40
# train loss: 0.8622018622154254
# validation loss: 0.8707086781660716
# validation Dice: 0.2621609367695876
# validation best threshold: 0.76
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 30/40
# train loss: 0.8596665503448276
# validation loss: 0.8638003093855722
# validation Dice: 0.27137561510896213
# validation best threshold: 0.82
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 31/40
# train loss: 0.8596769045129347
# validation loss: 0.8789672579084123
# validation Dice: 0.2672973573538973
# validation best threshold: 0.9
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 32/40
# train loss: 0.8581650806100745
# validation loss: 0.8596837259474255
# validation Dice: 0.2767670174866063
# validation best threshold: 0.7
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.2767670174866063
# threshold: 0.7
# epoch: 32
# lr: 0.0006
# pos_weight: 12
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 33/40
# train loss: 0.8600120642111062
# validation loss: 0.8661001057851883
# validation Dice: 0.2682849889998308
# validation best threshold: 0.82
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 34/40
# train loss: 0.8540056568156019
# validation loss: 0.8587988081432524
# validation Dice: 0.27683915747986365
# validation best threshold: 0.84
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.27683915747986365
# threshold: 0.84
# epoch: 34
# lr: 0.0006
# pos_weight: 12
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 35/40
# train loss: 0.8521164506673813
# validation loss: 0.8677855108465468
# validation Dice: 0.272837360925591
# validation best threshold: 0.4
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 36/40
# train loss: 0.8499235937897669
# validation loss: 0.8589048377105168
# validation Dice: 0.2727147646300839
# validation best threshold: 0.88
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 37/40
# train loss: 0.8511469138866407
# validation loss: 0.8561987465336209
# validation Dice: 0.27923260748547934
# validation best threshold: 0.84
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.27923260748547934
# threshold: 0.84
# epoch: 37
# lr: 0.0006
# pos_weight: 12
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 38/40
# train loss: 0.8463512440902765
# validation loss: 0.8594068146887279
# validation Dice: 0.2750340958268313
# validation best threshold: 0.82
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 39/40
# train loss: 0.8424049382717416
# validation loss: 0.8496686819053831
# validation Dice: 0.2832598322227014
# validation best threshold: 0.88
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.2832598322227014
# threshold: 0.88
# epoch: 39
# lr: 0.0006
# pos_weight: 12
# ******************************
# =============================================
# fasc lr=0.0006 pos_weight=12 epoch: 40/40
# train loss: 0.8415144159320439
# validation loss: 0.8522402808779762
# validation Dice: 0.28407208935332595
# validation best threshold: 0.88
#
# ***** GLOBAL BEST UPDATE *****
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# Dice: 0.28407208935332595
# threshold: 0.88
# epoch: 40
# lr: 0.0006
# pos_weight: 12
# ******************************
#
# =================================================
# fasc lr=0.0006 pos_weight=12
# lr: 0.0006
# pos_weight: 12
# train loss: 0.8415144159320439
# validation loss: 0.8522402808779762
# best epoch: 40
# best validation Dice: 0.28407208935332595
# best threshold: 0.88
# =================================================
#
#
# =============================================
# FASC BEST RESULT
# =============================================
# lr: 0.0006
# pos_weight: 12
# best epoch: 40
# best threshold: 0.88
# validation loss: 0.8522402808779762
# best validation Dice: 0.28407208935332595
# model: /content/drive/MyDrive/colab/UMUD/fasc_model.pth
# =============================================
#
# =============================================
# 実行開始時間: 2026-09-25 19:16:42 JST
# すべての処理が終了した時間: 2026-09-25 22:22:08 JST
# 総処理時間: 03:05:26
# =============================================
# Google Driveへの書き込みを確定します
# Google Driveへの保存が完了しました
# Colabランタイムを切断します
